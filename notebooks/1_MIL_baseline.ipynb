# %% [markdown]
# # Базлайн-решение
#
# В этом решении я буду обучать обычную _Unet_-модель, в качестве эндокера возьму _resnet50_, на выходе нейронной сети будет сверточный слой с 7 каналами (количество классов), оптимизатором выступит _Adam_ с шагом градиентного спуска 0.01 и стратегией понижения _ReduceLROnPlateau_, фунцией потерь - _IoULoss_ (т.к. будем максимизировать метрику _iou_), обучение будет проходить на 20 эпохах.

# %%
import re
import torch
import numpy as np
import pandas as pd
from pathlib import Path
from torch import nn, optim
import albumentations as albu
from catalyst.metrics import iou
from torch.utils.data import DataLoader
import segmentation_models_pytorch as smp
from catalyst.contrib.losses import IoULoss
from albumentations.pytorch import ToTensorV2 as ToTensor
from catalyst.callbacks import (IOUCallback, 
                                CriterionCallback, 
                                OptimizerCallback)
from utils import(create_sample, 
                  extract_ids, 
                  split_sample, 
                  PascalDataset, 
                  visualize, 
                  PascalRunner,
                  plot_metric,
                  extract_masks, 
                  extract_masks_label)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
src_path = Path("Pascal-part")
image_path = src_path / "JPEGImages"
mask_path = src_path / "gt_masks"

image_names = create_sample(image_path)
mask_names = create_sample(mask_path)

# %%
train_ids = extract_ids(src_path / "train_id.txt")
val_ids = extract_ids(src_path / "val_id.txt")

image_names_train, image_names_val = split_sample(image_names, train_ids, val_ids)
mask_names_train, mask_names_val = split_sample(mask_names, train_ids, val_ids)

# %%
classes = []
with open(src_path / "classes.txt") as file:
    for line in file:
        classes.append(re.sub("[^a-z_]+", "", line))

classes
# Out:
# ['bg', 'low_hand', 'torso', 'low_leg', 'head', 'up_leg', 'up_hand']

# %% [markdown]
# Чтобы избежать переобучения на обучающей выборке добавим аугментацию изображений:

# %%
p = 0.3
image_size = 224
n_classes = len(classes)

train_transforms = albu.Compose([
    albu.RandomResizedCrop(image_size, image_size),
    albu.Rotate(p=p),
    albu.HorizontalFlip(p=p),
    albu.VerticalFlip(p=p), 
    albu.GaussianBlur(p=p),
    albu.Normalize(),
    ToTensor()
])

val_transforms = albu.Compose([
    albu.Resize(image_size, image_size),
    albu.Normalize(),
    ToTensor()
])

train_dataset = PascalDataset(image_names_train, mask_names_train, n_classes, train_transforms)
val_dataset = PascalDataset(image_names_val, mask_names_val, n_classes, val_transforms)

# %% [markdown]
# Примеры исходных изображений с аугментацией:

# %%
np.random.seed(42)
n_examples = 3
mean = torch.tensor([0.485, 0.456, 0.406])
std = torch.tensor([0.229, 0.224, 0.225])

for i in range(n_examples):
    image, mask, mask_expanded = np.random.choice(train_dataset).values()
    image = image.permute(1, 2, 0)
    image = image * std + mean
    visualize(image=image, mask=mask)

# %%
num_epochs = 20
batch_size = 32
num_workers = 2
threshold = 0.5
logdir = "./logs/segmentation"

train_dataloader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
val_dataloader = DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
loaders = {
    "train": train_dataloader,
    "valid": val_dataloader
}
criterion = IoULoss()
model = smp.Unet("resnet50", classes=n_classes, activation=nn.Softmax2d)
optimizer = optim.Adam(model.parameters(), 1e-2)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=3)
callbacks = [
    CriterionCallback("pred", "mask_expanded", "loss_iou"),
    IOUCallback("pred", "mask_expanded", class_names=classes, threshold=threshold),
    OptimizerCallback("loss_iou")
]
runner = PascalRunner(input_key="image", output_key="pred",
                      output_mask_key="pred_mask", target_key="mask", 
                      loss_key="loss_iou", device=device)

# %%
runner.train(
    loaders=loaders,
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    callbacks=callbacks,
    num_epochs=num_epochs,
    logdir=logdir,
    valid_loader="valid",
    valid_metric="iou",
    minimize_valid_metric=False
)
# Out:
# train (1/20) iou: 0.13889887928962708 | iou/_macro: 0.13889887928962708 | iou/_micro: 0.4956549406051636 | loss_iou: 0.8559145934600315 | loss_iou/mean: 0.8559145934600315 | loss_iou/std: 0.02170418797573953 | lr: 0.01 | momentum: 0.9
# valid (1/20) iou: 0.12981688976287842 | iou/_macro: 0.12981688976287842 | iou/_micro: 0.41683685779571533 | loss_iou: 0.8654205710581033 | loss_iou/mean: 0.8654205710581033 | loss_iou/std: 0.011312596397903073 | lr: 0.01 | momentum: 0.9
# * Epoch (1/20) lr: 0.01 | momentum: 0.9
# train (2/20) iou: 0.1581106334924698 | iou/_macro: 0.1581106334924698 | iou/_micro: 0.505777895450592 | loss_iou: 0.8375976187745815 | loss_iou/mean: 0.8375976187745815 | loss_iou/std: 0.017569789235593068 | lr: 0.01 | momentum: 0.9
# valid (2/20) iou: 0.1370099037885666 | iou/_macro: 0.1370099037885666 | iou/_micro: 0.4328750967979431 | loss_iou: 0.8595503787002942 | loss_iou/mean: 0.8595503787002942 | loss_iou/std: 0.008130055138004034 | lr: 0.01 | momentum: 0.9
# * Epoch (2/20) lr: 0.01 | momentum: 0.9
# train (3/20) iou: 0.16699863970279694 | iou/_macro: 0.16699863970279694 | iou/_micro: 0.507738471031189 | loss_iou: 0.8333719177863654 | loss_iou/mean: 0.8333719177863654 | loss_iou/std: 0.016656596328667502 | lr: 0.01 | momentum: 0.9
# valid (3/20) iou: 0.16820648312568665 | iou/_macro: 0.16820648312568665 | iou/_micro: 0.5495054125785828 | loss_iou: 0.8324442547989699 | loss_iou/mean: 0.8324442547989699 | loss_iou/std: 0.014055662060980243 | lr: 0.01 | momentum: 0.9
# * Epoch (3/20) lr: 0.01 | momentum: 0.9
# train (4/20) iou: 0.17081379890441895 | iou/_macro: 0.17081379890441895 | iou/_micro: 0.4985964596271515 | loss_iou: 0.8291720597354219 | loss_iou/mean: 0.8291720597354219 | loss_iou/std: 0.017454165207593107 | lr: 0.01 | momentum: 0.9
# valid (4/20) iou: 0.18285654485225677 | iou/_macro: 0.18285654485225677 | iou/_micro: 0.5640348196029663 | loss_iou: 0.818964772548163 | loss_iou/mean: 0.818964772548163 | loss_iou/std: 0.01808749936616668 | lr: 0.01 | momentum: 0.9
# * Epoch (4/20) lr: 0.01 | momentum: 0.9
# train (5/20) iou: 0.18415673077106476 | iou/_macro: 0.18415673077106476 | iou/_micro: 0.5178383588790894 | loss_iou: 0.8158658578390781 | loss_iou/mean: 0.8158658578390781 | loss_iou/std: 0.019150960222927164 | lr: 0.01 | momentum: 0.9
# valid (5/20) iou: 0.1957441121339798 | iou/_macro: 0.1957441121339798 | iou/_micro: 0.615997314453125 | loss_iou: 0.80789885493957 | loss_iou/mean: 0.80789885493957 | loss_iou/std: 0.02058375796654935 | lr: 0.01 | momentum: 0.9
# * Epoch (5/20) lr: 0.005 | momentum: 0.9
# train (6/20) iou: 0.19267259538173676 | iou/_macro: 0.19267259538173676 | iou/_micro: 0.5210050940513611 | loss_iou: 0.8084307679536068 | loss_iou/mean: 0.8084307679536068 | loss_iou/std: 0.019928587048693158 | lr: 0.005 | momentum: 0.9
# valid (6/20) iou: 0.20638105273246765 | iou/_macro: 0.20638105273246765 | iou/_micro: 0.6099355220794678 | loss_iou: 0.7990230871562067 | loss_iou/mean: 0.7990230871562067 | loss_iou/std: 0.02205157082143804 | lr: 0.005 | momentum: 0.9
# * Epoch (6/20) lr: 0.005 | momentum: 0.9
# train (7/20) iou: 0.20075829327106476 | iou/_macro: 0.20075829327106476 | iou/_micro: 0.5295706391334534 | loss_iou: 0.799695607287953 | loss_iou/mean: 0.799695607287953 | loss_iou/std: 0.02029413134737778 | lr: 0.005 | momentum: 0.9
# valid (7/20) iou: 0.2044612467288971 | iou/_macro: 0.2044612467288971 | iou/_micro: 0.5965355038642883 | loss_iou: 0.7997852772937974 | loss_iou/mean: 0.7997852772937974 | loss_iou/std: 0.018203326602022802 | lr: 0.005 | momentum: 0.9
# * Epoch (7/20) lr: 0.005 | momentum: 0.9
# train (8/20) iou: 0.2045779675245285 | iou/_macro: 0.2045779675245285 | iou/_micro: 0.5347124934196472 | loss_iou: 0.795890747657163 | loss_iou/mean: 0.795890747657163 | loss_iou/std: 0.02108211100292893 | lr: 0.005 | momentum: 0.9
# valid (8/20) iou: 0.2134052813053131 | iou/_macro: 0.2134052813053131 | iou/_micro: 0.5762518048286438 | loss_iou: 0.7905906037528915 | loss_iou/mean: 0.7905906037528915 | loss_iou/std: 0.019704429092063956 | lr: 0.005 | momentum: 0.9
# * Epoch (8/20) lr: 0.005 | momentum: 0.9
# train (9/20) iou: 0.20577369630336761 | iou/_macro: 0.20577369630336761 | iou/_micro: 0.5363045930862427 | loss_iou: 0.7944362244535151 | loss_iou/mean: 0.7944362244535151 | loss_iou/std: 0.025118368282109258 | lr: 0.005 | momentum: 0.9
# valid (9/20) iou: 0.20948286354541779 | iou/_macro: 0.20948286354541779 | iou/_micro: 0.5748298764228821 | loss_iou: 0.7940175900027641 | loss_iou/mean: 0.7940175900027641 | loss_iou/std: 0.016842331188224247 | lr: 0.005 | momentum: 0.9
# * Epoch (9/20) lr: 0.0025 | momentum: 0.9
# train (10/20) iou: 0.20987285673618317 | iou/_macro: 0.20987285673618317 | iou/_micro: 0.5321931838989258 | loss_iou: 0.7902715223019458 | loss_iou/mean: 0.7902715223019458 | loss_iou/std: 0.02143250216762344 | lr: 0.0025 | momentum: 0.9
# valid (10/20) iou: 0.2327515035867691 | iou/_macro: 0.2327515035867691 | iou/_micro: 0.609582781791687 | loss_iou: 0.7722109329413828 | loss_iou/mean: 0.7722109329413828 | loss_iou/std: 0.02250200872376687 | lr: 0.0025 | momentum: 0.9
# * Epoch (10/20) lr: 0.0025 | momentum: 0.9
# train (11/20) iou: 0.20835252106189728 | iou/_macro: 0.20835252106189728 | iou/_micro: 0.5370606780052185 | loss_iou: 0.7915073818799373 | loss_iou/mean: 0.7915073818799373 | loss_iou/std: 0.023456788278599407 | lr: 0.0025 | momentum: 0.9
# valid (11/20) iou: 0.2358272224664688 | iou/_macro: 0.2358272224664688 | iou/_micro: 0.638403594493866 | loss_iou: 0.7692979715838291 | loss_iou/mean: 0.7692979715838291 | loss_iou/std: 0.021336516519501768 | lr: 0.0025 | momentum: 0.9
# * Epoch (11/20) lr: 0.0025 | momentum: 0.9
# train (12/20) iou: 0.20751462876796722 | iou/_macro: 0.20751462876796722 | iou/_micro: 0.5399142503738403 | loss_iou: 0.7926902703081391 | loss_iou/mean: 0.7926902703081391 | loss_iou/std: 0.021178051747431547 | lr: 0.0025 | momentum: 0.9
# valid (12/20) iou: 0.23664845526218414 | iou/_macro: 0.23664845526218414 | iou/_micro: 0.6231535077095032 | loss_iou: 0.7682919158288074 | loss_iou/mean: 0.7682919158288074 | loss_iou/std: 0.019403560690096414 | lr: 0.0025 | momentum: 0.9
# * Epoch (12/20) lr: 0.0025 | momentum: 0.9
# train (13/20) iou: 0.21054954826831818 | iou/_macro: 0.21054954826831818 | iou/_micro: 0.5415936708450317 | loss_iou: 0.7891621247977965 | loss_iou/mean: 0.7891621247977965 | loss_iou/std: 0.021602606146483832 | lr: 0.0025 | momentum: 0.9
# valid (13/20) iou: 0.23282106220722198 | iou/_macro: 0.23282106220722198 | iou/_micro: 0.6277138590812683 | loss_iou: 0.7720116815270257 | loss_iou/mean: 0.7720116815270257 | loss_iou/std: 0.021747162986695105 | lr: 0.0025 | momentum: 0.9
# * Epoch (13/20) lr: 0.00125 | momentum: 0.9
# train (14/20) iou: 0.21938838064670563 | iou/_macro: 0.21938838064670563 | iou/_micro: 0.5583348870277405 | loss_iou: 0.7804359962395212 | loss_iou/mean: 0.7804359962395212 | loss_iou/std: 0.025845471556033606 | lr: 0.00125 | momentum: 0.9
# valid (14/20) iou: 0.23377034068107605 | iou/_macro: 0.23377034068107605 | iou/_micro: 0.6379677057266235 | loss_iou: 0.77104538653831 | loss_iou/mean: 0.77104538653831 | loss_iou/std: 0.023082403980609716 | lr: 0.00125 | momentum: 0.9
# * Epoch (14/20) lr: 0.00125 | momentum: 0.9
# train (15/20) iou: 0.21735084056854248 | iou/_macro: 0.21735084056854248 | iou/_micro: 0.5466622114181519 | loss_iou: 0.7833853080942542 | loss_iou/mean: 0.7833853080942542 | loss_iou/std: 0.025238277801808182 | lr: 0.00125 | momentum: 0.9
# valid (15/20) iou: 0.24115458130836487 | iou/_macro: 0.24115458130836487 | iou/_micro: 0.6075848340988159 | loss_iou: 0.7630727785142848 | loss_iou/mean: 0.7630727785142848 | loss_iou/std: 0.019278882053349298 | lr: 0.00125 | momentum: 0.9
# * Epoch (15/20) lr: 0.00125 | momentum: 0.9
# train (16/20) iou: 0.21711699664592743 | iou/_macro: 0.21711699664592743 | iou/_micro: 0.5514681935310364 | loss_iou: 0.7833478037803122 | loss_iou/mean: 0.7833478037803122 | loss_iou/std: 0.023922780185267337 | lr: 0.00125 | momentum: 0.9
# valid (16/20) iou: 0.23812104761600494 | iou/_macro: 0.23812104761600494 | iou/_micro: 0.6381146311759949 | loss_iou: 0.7672199840424253 | loss_iou/mean: 0.7672199840424253 | loss_iou/std: 0.023809401126250258 | lr: 0.00125 | momentum: 0.9
# * Epoch (16/20) lr: 0.00125 | momentum: 0.9
# train (17/20) iou: 0.21956263482570648 | iou/_macro: 0.21956263482570648 | iou/_micro: 0.548479437828064 | loss_iou: 0.780901302029204 | loss_iou/mean: 0.780901302029204 | loss_iou/std: 0.02240950667521561 | lr: 0.00125 | momentum: 0.9
# valid (17/20) iou: 0.24324209988117218 | iou/_macro: 0.24324209988117218 | iou/_micro: 0.6065223217010498 | loss_iou: 0.7612923518603054 | loss_iou/mean: 0.7612923518603054 | loss_iou/std: 0.020688971946249822 | lr: 0.00125 | momentum: 0.9
# * Epoch (17/20) lr: 0.000625 | momentum: 0.9
# train (18/20) iou: 0.22077032923698425 | iou/_macro: 0.22077032923698425 | iou/_micro: 0.5458546280860901 | loss_iou: 0.7795777225528129 | loss_iou/mean: 0.7795777225528129 | loss_iou/std: 0.02082646471886869 | lr: 0.000625 | momentum: 0.9
# valid (18/20) iou: 0.24929870665073395 | iou/_macro: 0.24929870665073395 | iou/_micro: 0.6309756636619568 | loss_iou: 0.7551022326254947 | loss_iou/mean: 0.7551022326254947 | loss_iou/std: 0.019837327970502843 | lr: 0.000625 | momentum: 0.9
# * Epoch (18/20) lr: 0.000625 | momentum: 0.9
# train (19/20) iou: 0.22243593633174896 | iou/_macro: 0.22243593633174896 | iou/_micro: 0.5521888136863708 | loss_iou: 0.7776322437361971 | loss_iou/mean: 0.7776322437361971 | loss_iou/std: 0.02719727119466508 | lr: 0.000625 | momentum: 0.9
# valid (19/20) iou: 0.2444516122341156 | iou/_macro: 0.2444516122341156 | iou/_micro: 0.6207876801490784 | loss_iou: 0.7606632222212019 | loss_iou/mean: 0.7606632222212019 | loss_iou/std: 0.020060009840611657 | lr: 0.000625 | momentum: 0.9
# * Epoch (19/20) lr: 0.000625 | momentum: 0.9
# train (20/20) iou: 0.22163459658622742 | iou/_macro: 0.22163459658622742 | iou/_micro: 0.550714910030365 | loss_iou: 0.7785394098939243 | loss_iou/mean: 0.7785394098939243 | loss_iou/std: 0.021929354424078038 | lr: 0.000625 | momentum: 0.9
# valid (20/20) iou: 0.2436448633670807 | iou/_macro: 0.2436448633670807 | iou/_micro: 0.6377511620521545 | loss_iou: 0.7610696344260953 | loss_iou/mean: 0.7610696344260953 | loss_iou/std: 0.022257293016694556 | lr: 0.000625 | momentum: 0.9
# * Epoch (20/20) lr: 0.000625 | momentum: 0.9
# Top models:
# ./logs/segmentation/checkpoints/model.0018.pth	0.2493

# %%
csv_logger = Path(logdir) / "csv_logger"

train_df = pd.read_csv(csv_logger / "train.csv")
valid_df = pd.read_csv(csv_logger / "valid.csv")

# %% [markdown]
# Значение ключевой метрики во время обучения:

# %%
for metric_name in ["iou"]:
    plot_metric(train_df, valid_df, metric_name)

# %% [markdown]
# Модель не кажется переобученной, но качество оставляет желать лучшего.
#
# Примеры исходных изображений и предсказаний модели на валидационной выборке:

# %%
np.random.seed(42)

for i in range(n_examples):
    data = np.random.choice(val_dataset)
    dl = DataLoader([data])
    image, mask, mask_expanded = data.values()
    image = image.permute(1, 2, 0)
    image = image * std + mean
    pred_mask = torch.cat(list(runner.predict_loader(dl))).cpu().squeeze()
    visualize(image=image, mask=mask, pred_mask=pred_mask)

# %%
true_masks = torch.cat(list(extract_masks(val_dataloader))).to(device)
predicted_masks = torch.cat(list(runner.predict_loader(val_dataloader)))

# %%
body_labels = [[1, 6, 2, 4, 3, 5]]
up_low_labels = [[1, 6, 2, 4], [3, 5]]
parts_labels = list(range(1, n_classes))

true_masks0 = torch.stack(list(extract_masks_label(true_masks, body_labels)))
true_masks1 = torch.stack(list(extract_masks_label(true_masks, up_low_labels)))
true_masks2 = torch.stack(list(extract_masks_label(true_masks, parts_labels)))

predicted_masks0 = torch.stack(list(extract_masks_label(predicted_masks, body_labels)))
predicted_masks1 = torch.stack(list(extract_masks_label(predicted_masks, up_low_labels)))
predicted_masks2 = torch.stack(list(extract_masks_label(predicted_masks, parts_labels)))

# %% [markdown]
# Итоговые значения метрик на валидационной выборке:

# %%
iou0 = dict(zip(["body"], iou(true_masks0, predicted_masks0).cpu().numpy().round(3)))
pd.DataFrame(iou0, index=["iou0"])
# Out:
#        body
# iou0  0.405

# %%
iou1 = dict(zip(["upper_body", "lower_body"], iou(true_masks1, predicted_masks1).cpu().numpy().round(3)))
pd.DataFrame(iou1, index=["iou1"])
# Out:
#       upper_body  lower_body
# iou1         0.4       0.096

# %%
iou2 = dict(zip(classes[1:], iou(true_masks2, predicted_masks2).cpu().numpy().round(3)))
pd.DataFrame(iou2, index=["iou2"])
# Out:
#       low_hand  torso  low_leg   head  up_leg  up_hand
# iou2     0.168  0.235     0.03  0.347   0.068    0.049

# %% [markdown]
# ## Вывод:
# Качество базлайн-решения получилось неудовлетворительным.
